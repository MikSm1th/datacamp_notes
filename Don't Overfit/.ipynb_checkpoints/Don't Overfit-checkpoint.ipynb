# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn import preprocessing

train = pd.read_csv('train.csv', index_col='id')
train.head()
# Out:
#     target      0      1      2      3      4      5      6      7      8  \
# id
# 0      1.0 -0.098  2.165  0.681 -0.614  1.309 -0.455 -0.236  0.276 -2.246
# 1      0.0  1.081 -0.973 -0.383  0.326 -0.428  0.317  1.172  0.352  0.004
# 2      1.0 -0.523 -0.089 -0.348  0.148 -0.022  0.404 -0.023 -0.172  0.137
# 3      1.0  0.067 -0.021  0.392 -1.637 -0.446 -0.725 -1.035  0.834  0.503
# 4      1.0  2.347 -0.831  0.511 -0.021  1.225  1.594  0.585  1.509 -0.012
#
#     ...      290    291    292    293    294    295    296    297    298  \
# id  ...
# 0   ...    0.867  1.347  0.504 -0.649  0.672 -2.097  1.051 -0.414  1.038
# 1   ...   -0.165 -1.695 -1.257  1.359 -0.808 -1.624 -0.458 -1.099 -0.936
# 2   ...    0.013  0.263 -1.222  0.726  1.444 -1.165 -1.544  0.004  0.800
# 3   ...   -0.404  0.640 -0.595 -0.966  0.900  0.467 -0.562 -0.254 -0.533
# 4   ...    0.898  0.134  2.415 -0.996 -1.006  1.378  1.246  1.478  0.428
#
#       299
# id
# 0  -1.065
# 1   0.973
# 2  -1.211
# 3   0.238
# ...

# %%
from scipy.stats import zscore
# train['mean'] = train.loc[:, '1':].mean(axis=1)
# train['std'] = train.loc[:, '1':].std(axis=1)
# train_describe = train.apply(pd.DataFrame.describe, axis=1)
# train_describe['target'] = train['target']
# train_describe['diff'] = train_describe['max'] - train_describe['min']
# zscore = train.apply(zscore, axis=1)
# mn = [i.mean() for i in zscore]
# train_describe['zmean'] = mn
#train_describe

# %%
import seaborn as sns 
sns.set()
_ = sns.swarmplot(x='target', y='mean', data=train_describe)

# %%
_ = sns.swarmplot(x='target', y='diff', data=train_describe)

# %%
_ = sns.swarmplot(x='target', y='max', data=train_describe)

# %%
_ = sns.swarmplot(x='target', y='zmean', data=train_describe)
